# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/main/C4/W4/ungraded_labs/C4_W4_Lab_3_Sunspots_CNN_RNN_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Predicting Sunspots with Neural Networks
#
# At this point in the course, you should be able to explore different network architectures for forecasting. In the previous weeks, you've used DNNs, RNNs, and CNNs to build these different models. In the final practice lab for this course, you'll try one more configuration and that is a combination of all these types of networks: the data windows will pass through a convolution, followed by stacked LSTMs, followed by stacked dense layers. See if this improves results or you can just opt for simpler models.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ## Utilities

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# ## Download and Preview the Dataset

# %%
# Download the Dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv

# %%
Sun_spots_url = "https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv"  # shortcut URL
sunspots_file=tf.keras.utils.get_file('Sunspots.csv',Sun_spots_url)
sunspots_file
# Out:
# 'C:\\Users\\malat\\.keras\\datasets\\Sunspots.csv'

# %%
# Initialize lists
time_step = []
sunspots = []

# Open CSV file
# with open('./Sunspots.csv') as csvfile:
with open(sunspots_file) as csvfile:

  # Initialize reader
  reader = csv.reader(csvfile, delimiter=',')

  # Skip the first line
  next(reader)

  # Append row and sunspot number to lists
  for row in reader:
    time_step.append(int(row[0]))
    sunspots.append(float(row[2]))

# Convert lists to numpy arrays
time = np.array(time_step)
series = np.array(sunspots)

# Preview the data
plot_series(time, series, xlabel='Month', ylabel='Monthly Mean Total Sunspot Number')

# %%
series.max(),series.min()
# Out:
# (398.2, 0.0)

# %% [markdown]
# ## Split the Dataset

# %%
# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Prepare Features and Labels

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# As mentioned in the lectures, if your results don't look good, you can try tweaking the parameters here and see if the model will learn better.

# %%
# Parameters
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# Generate the dataset windows
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# You've seen these layers before and here is how it looks like when combined.

# %%
from tensorflow.keras import layers
# from tensorflow.keras.layers import Input,Dense,Conv1D,LSTM
from tensorflow.keras import Model

# %%
tf.keras.backend.clear_session()

# %%
def mul_four_hundred(ii):
    return ii*400
    # return tf.math.multiply(ii,400)

# %%
mul_four_hundred(2)
# Out:
# 800

# %% [markdown]
# ## for initial tests to evaluate models, We could run through small % of data and validate models, We could use less epochs also.
# ```
# history_model_api_bi_lstm = model_api_bi_lstm.fit(train_dataset,
#                               steps_per_epoch=int(0.1 * len(train_dataset)), # only fit on 10% of batches for faster training time
#                               epochs=3,
#                               validation_data=val_dataset,
#                               validation_steps=int(0.1 * len(val_dataset))) # only validate on 10% of batches
# ```

# %%
# Build the Model
def create_model_no_lmbda_fnc_api_mult():
    input_ly = layers.Input(shape=[None, 1])
    conv1D_ly = layers.Conv1D(filters=64, kernel_size=3,
                              strides=1,
                              activation="relu",
                              padding='causal')(input_ly)
    lstm_ly1 = layers.LSTM(64, return_sequences=True)(conv1D_ly)
    lstm_ly2 = layers.LSTM(64)(lstm_ly1)
    den_ly1 = layers.Dense(30, activation="relu")(lstm_ly2)
    den_ly2 = layers.Dense(10, activation="relu")(den_ly1)
    den_ly3 = layers.Dense(1)(den_ly2)
    output_ly = mul_four_hundred(den_ly3)
    model_ram_fnc_api = Model(input_ly, output_ly)
    return model_ram_fnc_api


model = create_model_no_lmbda_fnc_api_mult()
# Print the model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, 1)]         0
#
#  conv1d (Conv1D)             (None, None, 64)          256
#
#  lstm (LSTM)                 (None, None, 64)          33024
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 30)                1950
#
#  dense_1 (Dense)             (None, 10)                310
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  tf.math.multiply (TFOpLambd  (None, 1)                0
#  a)
#
# =================================================================
# Total params: 68,575
# Trainable params: 68,575
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Build the Model
def create_model_no_op_scal_fnc_api():
    input_ly=layers.Input(shape=[None,1])
    conv1D_ly=layers.Conv1D(filters=64, kernel_size=3,
                          strides=1,
                          activation="relu",
                          padding='causal')(input_ly)
    lstm_ly1=layers.LSTM(64, return_sequences=True)(conv1D_ly)
    lstm_ly2=layers.LSTM(64)(lstm_ly1)
    den_ly1=layers.Dense(30, activation="relu")(lstm_ly2)
    den_ly2=layers.Dense(10, activation="relu")(den_ly1)
    den_ly3=layers.Dense(1)(den_ly2)
    model_ram_fnc_api=Model(input_ly,den_ly3)
    return model_ram_fnc_api

# model=create_model_no_op_scal_fnc_api()
 # Print the model summary
# model.summary()

# %%
# Build the Model
def create_model():
    model=tf.keras.models.Sequential([
      tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                          strides=1,
                          activation="relu",
                          padding='causal',
                          input_shape=[None, 1]),
      tf.keras.layers.LSTM(64, return_sequences=True),
      tf.keras.layers.LSTM(64),
      tf.keras.layers.Dense(30, activation="relu"),
      tf.keras.layers.Dense(10, activation="relu"),
      tf.keras.layers.Dense(1),
      tf.keras.layers.Lambda(lambda x: x * 400)
    ])
    return model

# model=create_model()
#  # Print the model summary
# model.summary()

# %% [markdown]
# ## diff input_shape=[window_size, 1]

# %%
# # Build the Model
# model = tf.keras.models.Sequential([
#   tf.keras.layers.Conv1D(filters=64, kernel_size=3,
#                       strides=1,
#                       activation="relu",
#                       padding='causal',
#                       input_shape=[window_size, 1]),
#   tf.keras.layers.LSTM(64, return_sequences=True),
#   tf.keras.layers.LSTM(64),
#   tf.keras.layers.Dense(30, activation="relu"),
#   tf.keras.layers.Dense(10, activation="relu"),
#   tf.keras.layers.Dense(1),
#   tf.keras.layers.Lambda(lambda x: x * 400)
# ])
# 
#  # Print the model summary
# model.summary()

# %% [markdown]
# ## Tune the Learning Rate
#
# As usual, you will want to pick an optimal learning rate.

# %%
# Get initial weights
init_weights = model.get_weights()

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 93/93 [==============================] - 6s 15ms/step - loss: 102.2270 - lr: 1.0000e-08
# Epoch 2/100
# 93/93 [==============================] - 1s 10ms/step - loss: 66.6819 - lr: 1.1220e-08
# Epoch 3/100
# 93/93 [==============================] - 1s 10ms/step - loss: 55.5707 - lr: 1.2589e-08
# Epoch 4/100
# 93/93 [==============================] - 1s 10ms/step - loss: 51.1863 - lr: 1.4125e-08
# Epoch 5/100
# 93/93 [==============================] - 1s 10ms/step - loss: 48.5308 - lr: 1.5849e-08
# Epoch 6/100
# 93/93 [==============================] - 1s 10ms/step - loss: 46.7005 - lr: 1.7783e-08
# Epoch 7/100
# 93/93 [==============================] - 1s 10ms/step - loss: 45.2736 - lr: 1.9953e-08
# Epoch 8/100
# 93/93 [==============================] - 1s 10ms/step - loss: 43.9820 - lr: 2.2387e-08
# Epoch 9/100
# 93/93 [==============================] - 1s 9ms/step - loss: 42.6542 - lr: 2.5119e-08
# Epoch 10/100
# 93/93 [==============================] - 1s 10ms/step - loss: 41.2756 - lr: 2.8184e-08
# Epoch 11/100
# 93/93 [==============================] - 1s 9ms/step - loss: 39.9041 - lr: 3.1623e-08
# Epoch 12/100
# 93/93 [==============================] - 1s 9ms/step - loss: 38.5435 - lr: 3.5481e-08
# Epoch 13/100
# 93/93 [==============================] - 1s 9ms/step - loss: 36.8920 - lr: 3.9811e-08
# Epoch 14/100
# 93/93 [==============================] - 1s 9ms/step - loss: 34.7645 - lr: 4.4668e-08
# Epoch 15/100
# 93/93 [==============================] - 1s 9ms/step - loss: 32.7559 - lr: 5.0119e-08
# Epoch 16/100
# 93/93 [==============================] - 1s 9ms/step - loss: 31.1047 - lr: 5.6234e-08
# Epoch 17/100
# 93/93 [==============================] - 1s 9ms/step - loss: 29.6955 - lr: 6.3096e-08
# Epoch 18/100
# 93/93 [==============================] - 1s 9ms/step - loss: 28.5274 - lr: 7.0795e-08
# Epoch 19/100
# 93/93 [==============================] - 1s 9ms/step - loss: 27.5854 - lr: 7.9433e-08
# Epoch 20/100
# 93/93 [==============================] - 1s 9ms/step - loss: 26.5876 - lr: 8.9125e-08
# Epoch 21/100
# 93/93 [==============================] - 1s 9ms/step - loss: 25.9351 - lr: 1.0000e-07
# Epoch 22/100
# 93/93 [==============================] - 1s 9ms/step - loss: 25.6989 - lr: 1.1220e-07
# Epoch 23/100
# 93/93 [==============================] - 1s 9ms/step - loss: 24.1543 - lr: 1.2589e-07
# Epoch 24/100
# 93/93 [==============================] - 1s 9ms/step - loss: 23.6784 - lr: 1.4125e-07
# Epoch 25/100
# 93/93 [==============================] - 1s 9ms/step - loss: 25.5956 - lr: 1.5849e-07
# Epoch 26/100
# 93/93 [==============================] - 1s 9ms/step - loss: 24.0667 - lr: 1.7783e-07
# Epoch 27/100
# 93/93 [==============================] - 1s 9ms/step - loss: 23.6556 - lr: 1.9953e-07
# Epoch 28/100
# 93/93 [==============================] - 1s 9ms/step - loss: 23.9217 - lr: 2.2387e-07
# Epoch 29/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.6769 - lr: 2.5119e-07
# Epoch 30/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.6623 - lr: 2.8184e-07
# Epoch 31/100
# 93/93 [==============================] - 1s 10ms/step - loss: 21.4947 - lr: 3.1623e-07
# Epoch 32/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.9881 - lr: 3.5481e-07
# Epoch 33/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.3148 - lr: 3.9811e-07
# Epoch 34/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.5337 - lr: 4.4668e-07
# Epoch 35/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.8550 - lr: 5.0119e-07
# Epoch 36/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.4395 - lr: 5.6234e-07
# Epoch 37/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.9273 - lr: 6.3096e-07
# Epoch 38/100
# 93/93 [==============================] - 1s 10ms/step - loss: 18.7564 - lr: 7.0795e-07
# Epoch 39/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.5169 - lr: 7.9433e-07
# Epoch 40/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.3480 - lr: 8.9125e-07
# Epoch 41/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.7314 - lr: 1.0000e-06
# Epoch 42/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.1788 - lr: 1.1220e-06
# Epoch 43/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.4119 - lr: 1.2589e-06
# Epoch 44/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.4346 - lr: 1.4125e-06
# Epoch 45/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.6125 - lr: 1.5849e-06
# Epoch 46/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.2005 - lr: 1.7783e-06
# Epoch 47/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.0226 - lr: 1.9953e-06
# Epoch 48/100
# 93/93 [==============================] - 1s 8ms/step - loss: 18.5793 - lr: 2.2387e-06
# Epoch 49/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.8340 - lr: 2.5119e-06
# Epoch 50/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.7467 - lr: 2.8184e-06
# Epoch 51/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.3070 - lr: 3.1623e-06
# Epoch 52/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.9926 - lr: 3.5481e-06
# Epoch 53/100
# 93/93 [==============================] - 1s 8ms/step - loss: 18.3203 - lr: 3.9811e-06
# Epoch 54/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.3366 - lr: 4.4668e-06
# Epoch 55/100
# 93/93 [==============================] - 1s 10ms/step - loss: 20.4397 - lr: 5.0119e-06
# Epoch 56/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.9622 - lr: 5.6234e-06
# Epoch 57/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.9243 - lr: 6.3096e-06
# Epoch 58/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.1794 - lr: 7.0795e-06
# Epoch 59/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.9120 - lr: 7.9433e-06
# Epoch 60/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.8005 - lr: 8.9125e-06
# Epoch 61/100
# 93/93 [==============================] - 1s 10ms/step - loss: 20.7567 - lr: 1.0000e-05
# Epoch 62/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.0891 - lr: 1.1220e-05
# Epoch 63/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.4309 - lr: 1.2589e-05
# Epoch 64/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.8362 - lr: 1.4125e-05
# Epoch 65/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.3256 - lr: 1.5849e-05
# Epoch 66/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.2287 - lr: 1.7783e-05
# Epoch 67/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.7836 - lr: 1.9953e-05
# Epoch 68/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.1628 - lr: 2.2387e-05
# Epoch 69/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.7229 - lr: 2.5119e-05
# Epoch 70/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.2098 - lr: 2.8184e-05
# Epoch 71/100
# 93/93 [==============================] - 1s 9ms/step - loss: 23.8886 - lr: 3.1623e-05
# Epoch 72/100
# 93/93 [==============================] - 1s 10ms/step - loss: 21.7981 - lr: 3.5481e-05
# Epoch 73/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.4480 - lr: 3.9811e-05
# Epoch 74/100
# 93/93 [==============================] - 1s 10ms/step - loss: 21.2984 - lr: 4.4668e-05
# Epoch 75/100
# 93/93 [==============================] - 1s 10ms/step - loss: 24.0208 - lr: 5.0119e-05
# Epoch 76/100
# 93/93 [==============================] - 1s 9ms/step - loss: 22.9367 - lr: 5.6234e-05
# Epoch 77/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.0481 - lr: 6.3096e-05
# Epoch 78/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.9626 - lr: 7.0795e-05
# Epoch 79/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.3615 - lr: 7.9433e-05
# Epoch 80/100
# 93/93 [==============================] - 1s 8ms/step - loss: 21.6205 - lr: 8.9125e-05
# Epoch 81/100
# 93/93 [==============================] - 1s 8ms/step - loss: 25.1669 - lr: 1.0000e-04
# Epoch 82/100
# 93/93 [==============================] - 1s 9ms/step - loss: 31.3978 - lr: 1.1220e-04
# Epoch 83/100
# 93/93 [==============================] - 1s 9ms/step - loss: 26.9627 - lr: 1.2589e-04
# Epoch 84/100
# 93/93 [==============================] - 1s 9ms/step - loss: 24.3236 - lr: 1.4125e-04
# Epoch 85/100
# 93/93 [==============================] - 1s 9ms/step - loss: 25.7212 - lr: 1.5849e-04
# Epoch 86/100
# 93/93 [==============================] - 1s 9ms/step - loss: 29.3634 - lr: 1.7783e-04
# Epoch 87/100
# 93/93 [==============================] - 1s 9ms/step - loss: 32.8259 - lr: 1.9953e-04
# Epoch 88/100
# 93/93 [==============================] - 1s 8ms/step - loss: 33.4013 - lr: 2.2387e-04
# Epoch 89/100
# 93/93 [==============================] - 1s 9ms/step - loss: 39.4150 - lr: 2.5119e-04
# Epoch 90/100
# 93/93 [==============================] - 1s 9ms/step - loss: 51.6449 - lr: 2.8184e-04
# Epoch 91/100
# 93/93 [==============================] - 1s 9ms/step - loss: 40.0885 - lr: 3.1623e-04
# Epoch 92/100
# 93/93 [==============================] - 1s 9ms/step - loss: 54.5954 - lr: 3.5481e-04
# Epoch 93/100
# 93/93 [==============================] - 1s 9ms/step - loss: 57.0989 - lr: 3.9811e-04
# Epoch 94/100
# 93/93 [==============================] - 1s 8ms/step - loss: 58.6647 - lr: 4.4668e-04
# Epoch 95/100
# 93/93 [==============================] - 1s 8ms/step - loss: 70.6730 - lr: 5.0119e-04
# Epoch 96/100
# 93/93 [==============================] - 1s 9ms/step - loss: 62.2172 - lr: 5.6234e-04
# Epoch 97/100
# 93/93 [==============================] - 1s 10ms/step - loss: 64.4426 - lr: 6.3096e-04
# Epoch 98/100
# 93/93 [==============================] - 1s 10ms/step - loss: 71.1941 - lr: 7.0795e-04
# Epoch 99/100
# 93/93 [==============================] - 1s 10ms/step - loss: 59.4509 - lr: 7.9433e-04
# Epoch 100/100
# 93/93 [==============================] - 1s 9ms/step - loss: 70.6935 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# (1e-08, 0.001, 0.0, 100.0)

# %% [markdown]
# ## Train the Model
#
# Now you can proceed to reset and train the model. It is set for 100 epochs in the cell below but feel free to increase it if you want. Laurence got his results in the lectures after 500.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %% [markdown]
# ## learning rate plays a big role in loss reduction and accuracy

# %%
# Set the learning rate
# learning_rate = 8e-4
learning_rate = 8e-7

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %% [markdown]
# ##for initial tests to evaluate models, We could run through small % of data and validate models, We could use less epochs also.
#
# history_model_api_bi_lstm = model_api_bi_lstm.fit(train_dataset,
#                               steps_per_epoch=int(0.1 * len(train_dataset)), # only fit on 10% of batches for faster training time
#                               epochs=3,
#                               validation_data=val_dataset,
#                               validation_steps=int(0.1 * len(val_dataset))) # only validate on 10% of batches

# %%
# Train the model
history = model.fit(train_set,epochs=100)
# Out:
# Epoch 1/100
# 93/93 [==============================] - 4s 11ms/step - loss: 46.3071 - mae: 46.8034
# Epoch 2/100
# 93/93 [==============================] - 1s 9ms/step - loss: 29.2564 - mae: 29.7523
# Epoch 3/100
# 93/93 [==============================] - 1s 10ms/step - loss: 24.1161 - mae: 24.6100
# Epoch 4/100
# 93/93 [==============================] - 1s 10ms/step - loss: 22.3228 - mae: 22.8161
# Epoch 5/100
# 93/93 [==============================] - 1s 9ms/step - loss: 21.5301 - mae: 22.0231
# Epoch 6/100
# 93/93 [==============================] - 1s 9ms/step - loss: 20.4240 - mae: 20.9183
# Epoch 7/100
# 93/93 [==============================] - 1s 8ms/step - loss: 19.3646 - mae: 19.8553
# Epoch 8/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.5339 - mae: 20.0271
# Epoch 9/100
# 93/93 [==============================] - 1s 8ms/step - loss: 19.0780 - mae: 19.5713
# Epoch 10/100
# 93/93 [==============================] - 1s 9ms/step - loss: 19.3704 - mae: 19.8626
# Epoch 11/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.6583 - mae: 19.1514
# Epoch 12/100
# 93/93 [==============================] - 1s 10ms/step - loss: 18.5770 - mae: 19.0698
# Epoch 13/100
# 93/93 [==============================] - 1s 10ms/step - loss: 18.3237 - mae: 18.8164
# Epoch 14/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.1503 - mae: 18.6432
# Epoch 15/100
# 93/93 [==============================] - 1s 8ms/step - loss: 18.3756 - mae: 18.8685
# Epoch 16/100
# 93/93 [==============================] - 1s 8ms/step - loss: 18.0808 - mae: 18.5724
# Epoch 17/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.8778 - mae: 18.3699
# Epoch 18/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.7643 - mae: 18.2564
# Epoch 19/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.9228 - mae: 18.4162
# Epoch 20/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6736 - mae: 18.1651
# Epoch 21/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6615 - mae: 18.1540
# Epoch 22/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.1173 - mae: 18.6110
# Epoch 23/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.7236 - mae: 18.2168
# Epoch 24/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.5189 - mae: 18.0111
# Epoch 25/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.8552 - mae: 18.3474
# Epoch 26/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4948 - mae: 17.9869
# Epoch 27/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.0770 - mae: 18.5709
# Epoch 28/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.8994 - mae: 18.3922
# Epoch 29/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6604 - mae: 18.1531
# Epoch 30/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.4211 - mae: 17.9136
# Epoch 31/100
# 93/93 [==============================] - 1s 9ms/step - loss: 18.1066 - mae: 18.5989
# Epoch 32/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6136 - mae: 18.1065
# Epoch 33/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6180 - mae: 18.1106
# Epoch 34/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6161 - mae: 18.1075
# Epoch 35/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.7038 - mae: 18.1954
# Epoch 36/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.5577 - mae: 18.0506
# Epoch 37/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6212 - mae: 18.1129
# Epoch 38/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4637 - mae: 17.9567
# Epoch 39/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4912 - mae: 17.9830
# Epoch 40/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2863 - mae: 17.7784
# Epoch 41/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.5948 - mae: 18.0870
# Epoch 42/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3687 - mae: 17.8625
# Epoch 43/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4815 - mae: 17.9737
# Epoch 44/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6942 - mae: 18.1867
# Epoch 45/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3106 - mae: 17.8023
# Epoch 46/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6967 - mae: 18.1884
# Epoch 47/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6903 - mae: 18.1821
# Epoch 48/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6572 - mae: 18.1484
# Epoch 49/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4101 - mae: 17.9018
# Epoch 50/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4764 - mae: 17.9682
# Epoch 51/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3977 - mae: 17.8898
# Epoch 52/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6302 - mae: 18.1212
# Epoch 53/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2404 - mae: 17.7322
# Epoch 54/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2850 - mae: 17.7773
# Epoch 55/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4107 - mae: 17.9026
# Epoch 56/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.0996 - mae: 17.5915
# Epoch 57/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4980 - mae: 17.9907
# Epoch 58/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3737 - mae: 17.8652
# Epoch 59/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1730 - mae: 17.6624
# Epoch 60/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2068 - mae: 17.6998
# Epoch 61/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4247 - mae: 17.9172
# Epoch 62/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.6282 - mae: 18.1205
# Epoch 63/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.0149 - mae: 17.5072
# Epoch 64/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2158 - mae: 17.7074
# Epoch 65/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4010 - mae: 17.8916
# Epoch 66/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2281 - mae: 17.7200
# Epoch 67/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.0071 - mae: 17.4970
# Epoch 68/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1392 - mae: 17.6294
# Epoch 69/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3084 - mae: 17.7990
# Epoch 70/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1569 - mae: 17.6497
# Epoch 71/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1838 - mae: 17.6749
# Epoch 72/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4799 - mae: 17.9708
# Epoch 73/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.1984 - mae: 17.6895
# Epoch 74/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1205 - mae: 17.6126
# Epoch 75/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.5067 - mae: 17.9982
# Epoch 76/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.1036 - mae: 17.5933
# Epoch 77/100
# 93/93 [==============================] - 1s 9ms/step - loss: 16.9884 - mae: 17.4795
# Epoch 78/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3543 - mae: 17.8470
# Epoch 79/100
# 93/93 [==============================] - 1s 10ms/step - loss: 17.1704 - mae: 17.6612
# Epoch 80/100
# 93/93 [==============================] - 1s 10ms/step - loss: 17.0927 - mae: 17.5844
# Epoch 81/100
# 93/93 [==============================] - 1s 10ms/step - loss: 17.1653 - mae: 17.6565
# Epoch 82/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.1830 - mae: 17.6725
# Epoch 83/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1456 - mae: 17.6370
# Epoch 84/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4984 - mae: 17.9889
# Epoch 85/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.5071 - mae: 17.9980
# Epoch 86/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.0610 - mae: 17.5521
# Epoch 87/100
# 93/93 [==============================] - 1s 9ms/step - loss: 16.9718 - mae: 17.4640
# Epoch 88/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.2405 - mae: 17.7322
# Epoch 89/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.2326 - mae: 17.7246
# Epoch 90/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.0823 - mae: 17.5739
# Epoch 91/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.4131 - mae: 17.9057
# Epoch 92/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1535 - mae: 17.6452
# Epoch 93/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.3089 - mae: 17.8002
# Epoch 94/100
# 93/93 [==============================] - 1s 8ms/step - loss: 16.9086 - mae: 17.3995
# Epoch 95/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.0992 - mae: 17.5901
# Epoch 96/100
# 93/93 [==============================] - 1s 9ms/step - loss: 17.1705 - mae: 17.6626
# Epoch 97/100
# 93/93 [==============================] - 1s 8ms/step - loss: 16.9612 - mae: 17.4525
# Epoch 98/100
# 93/93 [==============================] - 1s 8ms/step - loss: 17.1008 - mae: 17.5932
# Epoch 99/100
# 93/93 [==============================] - 1s 9ms/step - loss: 16.9737 - mae: 17.4655
# Epoch 100/100
# 93/93 [==============================] - 1s 9ms/step - loss: 16.8755 - mae: 17.3678

# %% [markdown]
# You can visualize the training and see if the loss and MAE are still trending down.

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# ## Model Prediction
#
# As before, you can get the predictions for the validation set time range and compute the metrics.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)
print(x_valid.shape,forecast.shape)

# Drop single dimensional axis
results = forecast.squeeze()
print(results.shape)
# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 8/8 [==============================] - 1s 9ms/step
# (235,) (235, 1)
# (235,)

# %%
# Compute the MAE
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 15.504645

# %% [markdown]
# with fnc_api_ram_multiply - mae 17.09765

# %% [markdown]
# ## Wrap Up
#
# This concludes the final practice lab for this course! You implemented a deep and complex architecture composed of CNNs, RNNs, and DNNs. You'll be using the skills you developed throughout this course to complete the final assignment. Keep it up!

# %% [markdown]
# ## Optional
#
# In this optional section, you will look at another way to dynamically set the learning rate. As you may have noticed, training for a long time generates less and less changes to the loss and metrics. You can run the cell below to observe that again.

# %%
# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=10)
# Out:
# Epoch 1/10
# 93/93 [==============================] - 3s 10ms/step - loss: 16.6964 - mae: 17.1884
# Epoch 2/10
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6591 - mae: 17.1521
# Epoch 3/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.6565 - mae: 17.1467
# Epoch 4/10
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5872 - mae: 17.0781
# Epoch 5/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.6318 - mae: 17.1227
# Epoch 6/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5991 - mae: 17.0898
# Epoch 7/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.6070 - mae: 17.0987
# Epoch 8/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5784 - mae: 17.0697
# Epoch 9/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5920 - mae: 17.0830
# Epoch 10/10
# 93/93 [==============================] - 1s 8ms/step - loss: 16.6164 - mae: 17.1075

# %% [markdown]
# At some point, the static learning rate you set might no longer be the optimal one when the model has been learning for some time. You may want to decrease it some more to see better improvements. One way to do that is to have your training loop gradually decay the learning rate per epoch. You can pass in a lambda function similar like the one you did for the learning rate scheduler earlier, or use [ExponentialDecay()](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay). This is a built in scheduler from the Keras API. This decays the learning rate defined by this function:
#
# ```
# def decayed_learning_rate(step):
#   return initial_learning_rate * decay_rate ^ (step / decay_steps)
# ```
#
# See how it is used below.

# %%
# Set the initial learning rate
initial_learning_rate=1e-7

# Define the scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=400,
    decay_rate=0.96,
    staircase=True)

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=40)
# Out:
# Epoch 1/40
# 93/93 [==============================] - 2s 10ms/step - loss: 16.5804 - mae: 17.0716
# Epoch 2/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6039 - mae: 17.0942
# Epoch 3/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5983 - mae: 17.0899
# Epoch 4/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6153 - mae: 17.1068
# Epoch 5/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5900 - mae: 17.0811
# Epoch 6/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6016 - mae: 17.0930
# Epoch 7/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6206 - mae: 17.1117
# Epoch 8/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6041 - mae: 17.0954
# Epoch 9/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5804 - mae: 17.0723
# Epoch 10/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5757 - mae: 17.0672
# Epoch 11/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5975 - mae: 17.0890
# Epoch 12/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5945 - mae: 17.0868
# Epoch 13/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5810 - mae: 17.0726
# Epoch 14/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5746 - mae: 17.0658
# Epoch 15/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5856 - mae: 17.0776
# Epoch 16/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6081 - mae: 17.0988
# Epoch 17/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5924 - mae: 17.0835
# Epoch 18/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6107 - mae: 17.1020
# Epoch 19/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5614 - mae: 17.0526
# Epoch 20/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5668 - mae: 17.0579
# Epoch 21/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6708 - mae: 17.1618
# Epoch 22/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5563 - mae: 17.0472
# Epoch 23/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5560 - mae: 17.0469
# Epoch 24/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.6013 - mae: 17.0934
# Epoch 25/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5389 - mae: 17.0306
# Epoch 26/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5666 - mae: 17.0586
# Epoch 27/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5694 - mae: 17.0602
# Epoch 28/40
# 93/93 [==============================] - 1s 10ms/step - loss: 16.5492 - mae: 17.0398
# Epoch 29/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5673 - mae: 17.0584
# Epoch 30/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5714 - mae: 17.0630
# Epoch 31/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5565 - mae: 17.0479
# Epoch 32/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5554 - mae: 17.0462
# Epoch 33/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5649 - mae: 17.0553
# Epoch 34/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5455 - mae: 17.0367
# Epoch 35/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5636 - mae: 17.0540
# Epoch 36/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5502 - mae: 17.0415
# Epoch 37/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.6375 - mae: 17.1276
# Epoch 38/40
# 93/93 [==============================] - 1s 8ms/step - loss: 16.5608 - mae: 17.0506
# Epoch 39/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5514 - mae: 17.0436
# Epoch 40/40
# 93/93 [==============================] - 1s 9ms/step - loss: 16.5394 - mae: 17.0306

# %% [markdown]
# Now see the results by geting predicitons and computing the metrics.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 8/8 [==============================] - 0s 9ms/step

# %%
# Compute the MAE
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 14.171816

# %% [markdown]
# mae 14.65 with create_model_no_lmbda_fnc_api_mult

# %% [markdown]
# ideal mae=14.766848
